# %% [markdown]
# # Practice_1

# %% [markdown]
# # Pandas Functions

# %%
#filters all the warning not to display
import warnings
warnings.filterwarnings('ignore')

# %%
#pandas for reading files,data manipulation,basic information
import pandas as pd
#for visualisation(histogram,boxplot,scatterplot,pairplot,distrubutionplot)
import matplotlib.pyplot as plt
import seaborn as sn

# %%
#to read the content of universities and use as df
df=pd.read_csv('Universities.csv')

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#to show all the data in file
pd.set_option('display.min_row',None)

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#this function displays top 5 data
df.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
#this function shows last 5 data
df.tail()
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
df.head(10)
# Out:
#            Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0         Brown  1310     89      22       13     22704        94
# 1       CalTech  1415    100      25        6     63575        81
# 2           CMU  1260     62      59        9     25026        72
# 3      Columbia  1310     76      24       12     31510        88
# 4       Cornell  1280     83      33       13     21864        90
# 5     Dartmouth  1340     89      23       10     32162        95
# 6          Duke  1315     90      30       12     31585        95
# 7    Georgetown  1255     74      24       12     20126        92
# 8       Harvard  1400     91      14       11     39525        97
# 9  JohnsHopkins  1305     75      44        7     58691        87

# %%
df.tail(10)
# Out:
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 15      Purdue  1005     28      90       19      9066        69
# 16    Stanford  1360     90      20       12     36450        93
# 17    TexasA&M  1075     49      67       25      8704        67
# 18  UCBerkeley  1240     95      40       17     15140        78
# 19    UChicago  1290     75      50       13     38380        87
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96

# %%
#gives information of columns,memory and datatypee of file
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
#what type of file is 
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#describe the total information of the data
df.describe
# Out:
# <bound method NDFrame.describe of             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#gives the data types of data
df.dtypes
# Out:
# Univ        object
# SAT          int64
# Top10        int64
# Accept       int64
# SFRatio      int64
# Expenses     int64
# GradRate     int64
# dtype: object

# %%
#shape of data like no of rowS and columns
df.shape
# Out:
# (25, 7)

# %%
#tells any null values if found
df.isnull()
# Out:
#      Univ    SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0   False  False  False   False    False     False     False
# 1   False  False  False   False    False     False     False
# 2   False  False  False   False    False     False     False
# 3   False  False  False   False    False     False     False
# 4   False  False  False   False    False     False     False
# 5   False  False  False   False    False     False     False
# 6   False  False  False   False    False     False     False
# 7   False  False  False   False    False     False     False
# 8   False  False  False   False    False     False     False
# 9   False  False  False   False    False     False     False
# 10  False  False  False   False    False     False     False
# 11  False  False  False   False    False     False     False
# 12  False  False  False   False    False     False     False
# 13  False  False  False   False    False     False     False
# ...

# %%
#maximum value of every single column
df.max()
# Out:
# Univ         Yale
# SAT          1415
# Top10         100
# Accept         90
# SFRatio        25
# Expenses    63575
# GradRate       97
# dtype: object

# %%
#minimum value of every single column
df.min()
# Out:
# Univ        Brown
# SAT          1005
# Top10          28
# Accept         14
# SFRatio         6
# Expenses     8704
# GradRate       67
# dtype: object

# %%
#gives particular column values
df['SAT']
# Out:
# 0     1310
# 1     1415
# 2     1260
# 3     1310
# 4     1280
# 5     1340
# 6     1315
# 7     1255
# 8     1400
# 9     1305
# 10    1380
# 11    1260
# 12    1255
# 13    1081
# 14    1375
# 15    1005
# 16    1360
# 17    1075
# 18    1240
# 19    1290
# 20    1180
# 21    1285
# 22    1225
# 23    1085
# 24    1375
# Name: SAT, dtype: int64

# %%
#gives how many times the value is repeating
df['SAT'].value_counts()
# Out:
# 1310    2
# 1260    2
# 1255    2
# 1375    2
# 1005    1
# 1225    1
# 1285    1
# 1180    1
# 1290    1
# 1240    1
# 1075    1
# 1360    1
# 1081    1
# 1415    1
# 1380    1
# 1305    1
# 1400    1
# 1315    1
# 1340    1
# 1280    1
# 1085    1
# Name: SAT, dtype: int64

# %%
#to find the mean value
df['SAT'].min()
# Out:
# 1005

# %%
#to find the median value
df['SAT'].median()
# Out:
# 1285.0

# %%
#to find the mode of the value
df['SAT'].mode()
# Out:
# 0    1255
# 1    1260
# 2    1310
# 3    1375
# Name: SAT, dtype: int64

# %%
#to find the variance value
df['SAT'].var()
# Out:
# 11741.840000000002

# %%
#to find the standard deviation value
df['SAT'].std()
# Out:
# 108.35977113301782

# %%
df.mean()
# Out:
# SAT          1266.44
# Top10          76.48
# Accept         39.20
# SFRatio        12.72
# Expenses    27388.00
# GradRate       86.72
# dtype: float64

# %%
df.median()
# Out:
# SAT          1285.0
# Top10          81.0
# Accept         36.0
# SFRatio        12.0
# Expenses    27553.0
# GradRate       90.0
# dtype: float64

# %%
df.mode()
# Out:
#             Univ     SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1255.0   75.0    14.0     11.0      8704      95.0
# 1            CMU  1260.0   89.0    24.0     12.0      9066       NaN
# 2        CalTech  1310.0   90.0    30.0     13.0     10185       NaN
# 3       Columbia  1375.0   91.0    44.0      NaN     11857       NaN
# 4        Cornell     NaN   95.0     NaN      NaN     13349       NaN
# 5      Dartmouth     NaN    NaN     NaN      NaN     15122       NaN
# 6           Duke     NaN    NaN     NaN      NaN     15140       NaN
# 7     Georgetown     NaN    NaN     NaN      NaN     15470       NaN
# 8        Harvard     NaN    NaN     NaN      NaN     20126       NaN
# 9   JohnsHopkins     NaN    NaN     NaN      NaN     21864       NaN
# 10           MIT     NaN    NaN     NaN      NaN     22704       NaN
# 11  Northwestern     NaN    NaN     NaN      NaN     25026       NaN
# 12     NotreDame     NaN    NaN     NaN      NaN     27553       NaN
# ...

# %%
#to find the skewness of the column
df['SAT'].skew()
# Out:
# -0.9509096057089894

# %%
#to find the kurtosis of that column
df['SAT'].kurt()
# Out:
# 0.3551223727674433

# %%
#to copy the content of df into df1 
df1=df.copy()

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#double square brackets are used to fetch 2 or more columns
df[['SAT','Expenses']]
# Out:
#      SAT  Expenses
# 0   1310     22704
# 1   1415     63575
# 2   1260     25026
# 3   1310     31510
# 4   1280     21864
# 5   1340     32162
# 6   1315     31585
# 7   1255     20126
# 8   1400     39525
# 9   1305     58691
# 10  1380     34870
# 11  1260     28052
# 12  1255     15122
# 13  1081     10185
# 14  1375     30220
# 15  1005      9066
# 16  1360     36450
# 17  1075      8704
# 18  1240     15140
# 19  1290     38380
# 20  1180     15470
# 21  1285     27553
# 22  1225     13349
# 23  1085     11857
# 24  1375     43514

# %%
df[['SAT','Expenses']].mean()
# Out:
# SAT          1266.44
# Expenses    27388.00
# dtype: float64

# %%
#to find the index location
df.iloc[:,:]
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.iloc[2,3]
# Out:
# 59

# %%
df.iloc[2:4,1:3]
# Out:
#     SAT  Top10
# 2  1260     62
# 3  1310     76

# %%
df.groupby(['Accept']).mean()
# Out:
#            SAT  Top10  SFRatio  Expenses  GradRate
# Accept
# 14      1387.5   91.0      9.5   34872.5      96.0
# 19      1375.0   95.0     11.0   43514.0      96.0
# 20      1360.0   90.0     12.0   36450.0      93.0
# 22      1310.0   89.0     13.0   22704.0      94.0
# 23      1340.0   89.0     10.0   32162.0      95.0
# 24      1282.5   75.0     12.0   25818.0      90.0
# 25      1415.0  100.0      6.0   63575.0      81.0
# 30      1347.5   92.0     11.0   33227.5      93.0
# 33      1280.0   83.0     13.0   21864.0      90.0
# 36      1285.0   80.0     11.0   27553.0      90.0
# 39      1260.0   85.0     11.0   28052.0      89.0
# 40      1240.0   95.0     17.0   15140.0      78.0
# 42      1255.0   81.0     13.0   15122.0      94.0
# 44      1265.0   76.0     10.5   36020.0      89.5
# 50      1290.0   75.0     13.0   38380.0      87.0
# 54      1081.0   38.0     18.0   10185.0      80.0
# 59      1260.0   62.0      9.0   25026.0      72.0
# ...

# %% [markdown]
# # Visualization-Distrubution plot

# %%
#histogram of SAT column
plt.hist(df['SAT'])
# Out:
# (array([1., 3., 0., 0., 1., 2., 7., 4., 2., 5.]),
#  array([1005., 1046., 1087., 1128., 1169., 1210., 1251., 1292., 1333.,
#         1374., 1415.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(df['SAT'],df['Accept'],df['Top10'],'rs')

# %%
sn.histplot(df['SAT'])
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Count'>

# %%
sn.pairplot(df.iloc[:,:])

# %%
plt.plot(df['SAT'],df['Accept'],'rs')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.title('SAT vs Accept')
# Out:
# Text(0.5, 1.0, 'SAT vs Accept')
