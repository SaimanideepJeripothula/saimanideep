# %% [markdown]
# #  visualization using pandas,seaborn,matplotlib.pyplot libs.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
df=pd.read_csv('Universities.csv')

# %%
print(df)
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#to plot histogram for SAT
plt.hist(df['SAT'])
plt.show()

# %%
df['SAT'].min()
# Out:
# 1005

# %%
#to show all the content of file
pd.set_option('display.min_rows',None)

# %%
 df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
#histogram for Accept column
plt.hist(df['Accept'])
plt.show()

# %%
#shape give us no. of rows and column
df.shape
# Out:
# (25, 7)

# %%
#histogram using seaborn library
sn.histplot(df['SAT'])
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Count'>

# %%
sn.histplot(df['Accept'])
# Out:
# <AxesSubplot:xlabel='Accept', ylabel='Count'>

# %%
plt.plot(df['SAT'],df['Accept'],'rs')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.title('SAT vs Accept')
# Out:
# Text(0.5, 1.0, 'SAT vs Accept')

# %%
# scatterplot of 2 columns
sn.scatterplot(df['SAT'],df['Accept'])
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Accept'>

# %%
# to show all the histogram and scatterplot
sn.pairplot(df.iloc[:,:])

# %%
# to get all the graphs of the data
sn.pairplot(df)

# %%
#for the distribution plot of the column with hsitogram
sn.distplot(df['SAT'])
# Out:
# <AxesSubplot:xlabel='SAT', ylabel='Density'>

# %%
# to get the boxplot of the column
plt.boxplot(df['SAT'],vert=False)
plt.xlabel('SAT score')
plt.ylabel('Values')
plt.title('boxplot of SAT')
plot.show()

# %%
plt.boxplot(df['Accept'])
plt.xlabel('accept')
plt.ylabel('values')
plt.title('boxplot of Accept')
plt.show()
